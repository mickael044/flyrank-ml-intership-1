# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Over time, old web pages start losing their rankings and search traffic. Instead of spending a lot of time creating completely new content from scratch, fixing and updating existing pages is a much faster and cheaper way to get that lost traffic back

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Deciding if an editor should spend their working hours updating a specific old page or focus on something else.
#
# Action: Updating, adding fresh information, and re-optimizing the selected page.
#
# Cost of a Wrong Call:
#
#     False Positive: Spending hours fixing a page that ends up getting zero extra traffic anyway.
#
#     False Negative: Ignoring a high-value page that could have easily brought back thousands of visitors if we just updated it

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

total_pages = len(df)

if "trend_direction" in df.columns:
    declining_pages = (df["trend_direction"] == "down").sum()
    pct_declining = (declining_pages / total_pages) * 100
    print(f"Total pages in sample: {total_pages}")
    print(f"Pages dropping in traffic: {declining_pages} ({pct_declining:.1f}%)")
else:
    print(f"Total pages in sample: {total_pages}")
    print("Dataset columns:", list(df.columns[:5]))
# Out:
# Total pages in sample: 30000
# Pages dropping in traffic: 16262 (54.2%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can spot historical traffic drop trends and build a helpful model that recommends which pages are most likely worth refreshing based on the data.
#
# What I cannot claim: I cannot prove exactly how Google's ranking algorithm works internally, nor can I guarantee that a refreshed page will definitely hit #1 on search results

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
